# %%
# 0 - Primero instalo pandas
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\usuario\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# 0 - Cargo las librerías que necesito para el ejercicio de ML

#from utils import plot_decision_boundary, poly_linear_regression, CM_BRIGHT

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")
# %matplotlib inline

# %%
# 0 - También cargo la librería sklearn 
import sklearn
sklearn.__version__
# Out:
# '1.5.1'

# %%
# 1 - Ahora empezamos la preparación de datos 
# 1.1 - Cargamos el dataset de airbnb

airbnb = pd.read_csv("airbnb-listings-extract.csv", sep=";")
airbnb.head(4)
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0  11210388  https://www.airbnb.com/rooms/11210388  20170306202425
# 1  17471131  https://www.airbnb.com/rooms/17471131  20170407214050
# 2  17584891  https://www.airbnb.com/rooms/17584891  20170407214050
# 3   5398030   https://www.airbnb.com/rooms/5398030  20170407214050
#
#   Last Scraped                                 Name  \
# 0   2017-03-07       The Loft-Full Bath-Deck w/View
# 1   2017-04-08           Claris I, Friendly Rentals
# 2   2017-04-08  Style Terrace Red, Friendly Rentals
# 3   2017-04-08    Picasso Suite 1.4 Paseo de Gracia
#
#                                              Summary  \
# 0  Loft in the Hill country 12-15 minutes directl...
# 1  This apartment has: 1 double bed, 1 double sof...
# 2  This apartment has: 1 double bed, 1 double sof...
# 3  Live like a local in Barcelona's most chic dis...
#
#                                                Space  \
# 0  This loft has a spectacular view of the hills ...
# 1  This apartment has: 1 double bed, 1 double sof...
# 2  This apartment has: 1 double bed, 1 double sof...
# 3  You wake up to the sun rising over Barcelona's...
#
#                                          Description Experiences Offered  \
# 0  Loft in the Hill country 12-15 minutes directl...                none
# 1  This apartment has: 1 double bed, 1 double sof...                none
# 2  This apartment has: 1 double bed, 1 double sof...                none
# 3  Live like a local in Barcelona's most chic dis...                none
#
#                                Neighborhood Overview  ...  \
# 0  This neighborhood is located in the hills west...  ...
# 1  Plaza   Cataluña Catalonia Square is the large...  ...
# 2  Plaza   Cataluña Catalonia Square is the large...  ...
# 3  We're right in the heart of the chic L'Eixampl...  ...
#
#   Review Scores Communication Review Scores Location Review Scores Value  \
# 0                        10.0                   10.0                10.0
# 1                        10.0                    8.0                10.0
# 2                         NaN                    NaN                 NaN
# 3                        10.0                   10.0                 9.0
#
#        License Jurisdiction Names Cancellation Policy  \
# 0          NaN                NaN            moderate
# 1  HUTB-006721                NaN     super_strict_30
# 2  HUTB-007527                NaN     super_strict_30
# 3          NaN                NaN              strict
#
#   Calculated host listings count Reviews per Month  \
# 0                            1.0              3.50
# 1                          106.0              0.86
# 2                          106.0               NaN
# 3                           24.0              1.09
#
#                     Geolocation  \
# 0  30.3373609355,-97.8632766782
# 1   41.3896829422,2.17262543017
# 2   41.3930345489,2.16217327868
# 3    41.3969668101,2.1674178103
#
#                                             Features
# 0  Host Is Superhost,Host Has Profile Pic,Host Id...
# 1  Host Has Profile Pic,Requires License,Instant ...
# 2  Host Has Profile Pic,Requires License,Instant ...
# 3  Host Has Profile Pic,Host Identity Verified,Re...
#
# [4 rows x 89 columns]

# %%
# 1.2 - A continuación se eliminan las columnas no relevantes para el estudio (IDs, URLs, etc). Primero listo las cabeceras para saber qué columnas eliminar

print(airbnb.columns)
# Out:
# Index(['ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary',
#        'Space', 'Description', 'Experiences Offered', 'Neighborhood Overview',
#        'Notes', 'Transit', 'Access', 'Interaction', 'House Rules',
#        'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url',
#        'Host ID', 'Host URL', 'Host Name', 'Host Since', 'Host Location',
#        'Host About', 'Host Response Time', 'Host Response Rate',
#        'Host Acceptance Rate', 'Host Thumbnail Url', 'Host Picture Url',
#        'Host Neighbourhood', 'Host Listings Count',
#        'Host Total Listings Count', 'Host Verifications', 'Street',
#        'Neighbourhood', 'Neighbourhood Cleansed',
#        'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
#        'Smart Location', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
#        'Beds', 'Bed Type', 'Amenities', 'Square Feet', 'Price', 'Weekly Price',
#        'Monthly Price', 'Security Deposit', 'Cleaning Fee', 'Guests Included',
#        'Extra People', 'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
#        'Has Availability', 'Availability 30', 'Availability 60',
#        'Availability 90', 'Availability 365', 'Calendar last Scraped',
#        'Number of Reviews', 'First Review', 'Last Review',
#        'Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'License', 'Jurisdiction Names',
#        'Cancellation Policy', 'Calculated host listings count',
#        'Reviews per Month', 'Geolocation', 'Features'],
#       dtype='object')

# %%
# 1.2 Eliminación de las columnas. 

airbnb = airbnb.drop(['ID','Listing Url','Scrape ID','Last Scraped','Space','Description','Neighborhood Overview','Notes','Transit','Access','Interaction','House Rules','Thumbnail Url','Medium Url','Picture Url','XL Picture Url','Host ID','Host URL','Host Name','Host About','Host Thumbnail Url','Host Picture Url','Host Verifications','Market','Smart Location','Country Code','Weekly Price','Monthly Price','Maximum Nights','Calendar Updated','Has Availability','First Review','Last Review','Review Scores Rating','Review Scores Accuracy','Review Scores Cleanliness','Review Scores Checkin','Review Scores Communication','Review Scores Location','Review Scores Value','License','Jurisdiction Names','Name','Summary','Experiences Offered','Host Since','Host Location','Host Response Time','Host Response Rate','Host Acceptance Rate','Host Neighbourhood','Host Listings Count','Host Total Listings Count','Neighbourhood Cleansed','Neighbourhood Group Cleansed','State','Latitude','Longitude','Calendar last Scraped','Cancellation Policy','Geolocation','Features','Calculated host listings count', 'Availability 30', 'Availability 60', 'Availability 90', 'Availability 365'], axis=1)
airbnb.head(5).T
# Out:
#                                                                    0  \
# Street             Canyon Edge Drive, Austin, TX 78733, United St...
# Neighbourhood                                                    NaN
# City                                                          Austin
# Zipcode                                                        78733
# Country                                                United States
# Property Type                                                   Loft
# Room Type                                            Entire home/apt
# Accommodates                                                       2
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Cable TV,Internet,Wireless Internet,Air con...
# Square Feet                                                      NaN
# Price                                                           58.0
# Security Deposit                                               100.0
# Cleaning Fee                                                     NaN
# Guests Included                                                    1
# Extra People                                                       0
# Minimum Nights                                                     2
# Number of Reviews                                                 42
# Reviews per Month                                                3.5
#
#                                                                    1  \
# Street                             Barcelona, Barcelona 08010, Spain
# Neighbourhood                                                    NaN
# City                                                       Barcelona
# Zipcode                                                        08010
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                            Entire home/apt
# Accommodates                                                       4
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          Wireless Internet,Air conditioning,Elevator in...
# Square Feet                                                      NaN
# Price                                                           70.0
# Security Deposit                                               200.0
# Cleaning Fee                                                    40.0
# Guests Included                                                    2
# Extra People                                                      44
# Minimum Nights                                                     1
# Number of Reviews                                                  1
# Reviews per Month                                               0.86
#
#                                                                    2  \
# Street                             Barcelona, Barcelona 08008, Spain
# Neighbourhood                                                    NaN
# City                                                       Barcelona
# Zipcode                                                        08008
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                            Entire home/apt
# Accommodates                                                       4
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          Wireless Internet,Air conditioning,Elevator in...
# Square Feet                                                      NaN
# Price                                                           70.0
# Security Deposit                                               200.0
# Cleaning Fee                                                    60.0
# Guests Included                                                    2
# Extra People                                                      42
# Minimum Nights                                                     1
# Number of Reviews                                                  0
# Reviews per Month                                                NaN
#
#                                                                    3  \
# Street                             Barcelona, Barcelona 08009, Spain
# Neighbourhood                                                    NaN
# City                                                       Barcelona
# Zipcode                                                        08009
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                            Entire home/apt
# Accommodates                                                       8
# Bathrooms                                                        2.0
# Bedrooms                                                         3.0
# Beds                                                             4.0
# Bed Type                                                    Real Bed
# Amenities          TV,Internet,Wireless Internet,Air conditioning...
# Square Feet                                                      NaN
# Price                                                          229.0
# Security Deposit                                               250.0
# Cleaning Fee                                                    79.0
# Guests Included                                                    2
# Extra People                                                      39
# Minimum Nights                                                     2
# Number of Reviews                                                 13
# Reviews per Month                                               1.09
#
#                                                                    4
# Street             L'Antiga Esquerra de l'Eixample, Barcelona, Ca...
# Neighbourhood                        L'Antiga Esquerra de l'Eixample
# City                                                       Barcelona
# Zipcode                                                        08036
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                            Entire home/apt
# Accommodates                                                       5
# Bathrooms                                                        1.0
# Bedrooms                                                         2.0
# Beds                                                             2.0
# Bed Type                                                    Real Bed
# Amenities          TV,Wireless Internet,Air conditioning,Kitchen,...
# Square Feet                                                      NaN
# Price                                                          149.0
# Security Deposit                                                 NaN
# Cleaning Fee                                                    55.0
# Guests Included                                                    1
# Extra People                                                       0
# Minimum Nights                                                     2
# Number of Reviews                                                  0
# Reviews per Month                                                NaN

# %%
# 1.3 - Nos quedamos sólo con las muestras que son de Madrid

airbnb_Madrid = airbnb[airbnb['City'] == "Madrid"]

airbnb_Madrid.head(5).T
print(airbnb_Madrid.shape)
# Out:
# (13207, 22)

# %%
# 1.4 Observando las características, vemos que sólo hay datos en 'Square Feet' en 314 filas, por lo que haremos un modelo con los datos que tienen esta característica informada
# Podríamos dividir el dataframe en 2, uno con Square Feet informado y otro no, con el resto de datos.
# En la anterior versión hemos supuesto los datos NaN con la media y no ha salido un buen modelo

airbnb_Madrid_sf = airbnb_Madrid[(airbnb['Square Feet'] > 0)]
airbnb_Madrid_Nsf = airbnb_Madrid[(airbnb['Square Feet'] == 0) | (airbnb_Madrid['Square Feet'].isnull())]
print (airbnb_Madrid_Nsf.shape)
# Out:
# (12893, 22)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\2370392067.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   airbnb_Madrid_sf = airbnb_Madrid[(airbnb['Square Feet'] > 0)]
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\2370392067.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   airbnb_Madrid_Nsf = airbnb_Madrid[(airbnb['Square Feet'] == 0) | (airbnb_Madrid['Square Feet'].isnull())]

# %%
# 1.4 Ahora hacemos la división entre train y test


#from sklearn.model_selection import train_test_split

#train, test = train_test_split(airbnb_Madrid_sf, test_size=0.1, shuffle=True, random_state=0)

train = airbnb_Madrid_sf
test = airbnb_Madrid_Nsf

print(f'Dimensiones del dataset de training: {train.shape}')
print(f'Dimensiones del dataset de test: {test.shape}')

# Guardamos
train.to_csv('./airbnb_Madrid_Nsf_train.csv', sep=';', decimal='.', index=False)
test.to_csv('./airbnb_Madrid_Nsf_test.csv', sep=';', decimal='.', index=False)

# A partir de este momento cargamos el dataset de train y trabajamos ÚNICAMENTE con él. 

airbnb_Madrid_Nsf_train = pd.read_csv('./airbnb_Madrid_Nsf_train.csv', sep=';', decimal='.')
airbnb_Madrid_Nsf_train.head(5).T
# Out:
# Dimensiones del dataset de training: (314, 22)
# Dimensiones del dataset de test: (12893, 22)
#                                                                    0  \
# Street                                   Madrid, Madrid 28035, Spain
# Neighbourhood                                    Fuencarral-El Pardo
# City                                                          Madrid
# Zipcode                                                      28035.0
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                               Private room
# Accommodates                                                       1
# Bathrooms                                                        2.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Internet,Wireless Internet,Wheelchair acces...
# Square Feet                                                    969.0
# Price                                                           23.0
# Security Deposit                                               100.0
# Cleaning Fee                                                    10.0
# Guests Included                                                   15
# Extra People                                                      15
# Minimum Nights                                                     1
# Number of Reviews                                                  1
# Reviews per Month                                               0.06
#
#                                                                    1  \
# Street                           Aluche, Madrid, Madrid 28011, Spain
# Neighbourhood                                                 Aluche
# City                                                          Madrid
# Zipcode                                                      28011.0
# Country                                                        Spain
# Property Type                                                   Dorm
# Room Type                                               Private room
# Accommodates                                                       2
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Wireless Internet,Wheelchair accessible,Smo...
# Square Feet                                                     43.0
# Price                                                           50.0
# Security Deposit                                                 NaN
# Cleaning Fee                                                     NaN
# Guests Included                                                    1
# Extra People                                                       0
# Minimum Nights                                                     1
# Number of Reviews                                                  0
# Reviews per Month                                                NaN
#
#                                                                    2  \
# Street              Aluche, Madrid, Community of Madrid 28044, Spain
# Neighbourhood                                                 Aluche
# City                                                          Madrid
# Zipcode                                                      28044.0
# Country                                                        Spain
# Property Type                                                   Tent
# Room Type                                               Private room
# Accommodates                                                       2
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Internet,Wireless Internet,Air conditioning...
# Square Feet                                                    646.0
# Price                                                           25.0
# Security Deposit                                               100.0
# Cleaning Fee                                                     9.0
# Guests Included                                                    1
# Extra People                                                       6
# Minimum Nights                                                     1
# Number of Reviews                                                 13
# Reviews per Month                                               0.47
#
#                                                                    3  \
# Street                  Palos do Moguer, Madrid, Madrid 28045, Spain
# Neighbourhood                                        Palos do Moguer
# City                                                          Madrid
# Zipcode                                                      28045.0
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                               Private room
# Accommodates                                                       1
# Bathrooms                                                        1.5
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Wireless Internet,Wheelchair accessible,Doo...
# Square Feet                                                    108.0
# Price                                                           22.0
# Security Deposit                                                 NaN
# Cleaning Fee                                                     NaN
# Guests Included                                                    1
# Extra People                                                       0
# Minimum Nights                                                     1
# Number of Reviews                                                  7
# Reviews per Month                                               0.12
#
#                                                                    4
# Street                              Sol, Madrid, Madrid 28013, Spain
# Neighbourhood                                                    Sol
# City                                                          Madrid
# Zipcode                                                      28013.0
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                            Entire home/apt
# Accommodates                                                       4
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             2.0
# Bed Type                                                    Real Bed
# Amenities          TV,Internet,Wireless Internet,Air conditioning...
# Square Feet                                                    915.0
# Price                                                           70.0
# Security Deposit                                                 NaN
# Cleaning Fee                                                    30.0
# Guests Included                                                    2
# Extra People                                                       8
# Minimum Nights                                                     3
# Number of Reviews                                                  7
# Reviews per Month                                               0.12

# %%
# 2 Aquí empieza el análisis exploratorio de los datos del dataset
# 2.1 - Cabeceras (head) - Después de eliminar las columnas sobrantes, quedan 22 columnas de datos (o características). 

airbnb_Madrid_Nsf_train.head().T
# Out:
#                                                                    0  \
# Street                                   Madrid, Madrid 28035, Spain
# Neighbourhood                                    Fuencarral-El Pardo
# City                                                          Madrid
# Zipcode                                                      28035.0
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                               Private room
# Accommodates                                                       1
# Bathrooms                                                        2.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Internet,Wireless Internet,Wheelchair acces...
# Square Feet                                                    969.0
# Price                                                           23.0
# Security Deposit                                               100.0
# Cleaning Fee                                                    10.0
# Guests Included                                                   15
# Extra People                                                      15
# Minimum Nights                                                     1
# Number of Reviews                                                  1
# Reviews per Month                                               0.06
#
#                                                                    1  \
# Street                           Aluche, Madrid, Madrid 28011, Spain
# Neighbourhood                                                 Aluche
# City                                                          Madrid
# Zipcode                                                      28011.0
# Country                                                        Spain
# Property Type                                                   Dorm
# Room Type                                               Private room
# Accommodates                                                       2
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Wireless Internet,Wheelchair accessible,Smo...
# Square Feet                                                     43.0
# Price                                                           50.0
# Security Deposit                                                 NaN
# Cleaning Fee                                                     NaN
# Guests Included                                                    1
# Extra People                                                       0
# Minimum Nights                                                     1
# Number of Reviews                                                  0
# Reviews per Month                                                NaN
#
#                                                                    2  \
# Street              Aluche, Madrid, Community of Madrid 28044, Spain
# Neighbourhood                                                 Aluche
# City                                                          Madrid
# Zipcode                                                      28044.0
# Country                                                        Spain
# Property Type                                                   Tent
# Room Type                                               Private room
# Accommodates                                                       2
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Internet,Wireless Internet,Air conditioning...
# Square Feet                                                    646.0
# Price                                                           25.0
# Security Deposit                                               100.0
# Cleaning Fee                                                     9.0
# Guests Included                                                    1
# Extra People                                                       6
# Minimum Nights                                                     1
# Number of Reviews                                                 13
# Reviews per Month                                               0.47
#
#                                                                    3  \
# Street                  Palos do Moguer, Madrid, Madrid 28045, Spain
# Neighbourhood                                        Palos do Moguer
# City                                                          Madrid
# Zipcode                                                      28045.0
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                               Private room
# Accommodates                                                       1
# Bathrooms                                                        1.5
# Bedrooms                                                         1.0
# Beds                                                             1.0
# Bed Type                                                    Real Bed
# Amenities          TV,Wireless Internet,Wheelchair accessible,Doo...
# Square Feet                                                    108.0
# Price                                                           22.0
# Security Deposit                                                 NaN
# Cleaning Fee                                                     NaN
# Guests Included                                                    1
# Extra People                                                       0
# Minimum Nights                                                     1
# Number of Reviews                                                  7
# Reviews per Month                                               0.12
#
#                                                                    4
# Street                              Sol, Madrid, Madrid 28013, Spain
# Neighbourhood                                                    Sol
# City                                                          Madrid
# Zipcode                                                      28013.0
# Country                                                        Spain
# Property Type                                              Apartment
# Room Type                                            Entire home/apt
# Accommodates                                                       4
# Bathrooms                                                        1.0
# Bedrooms                                                         1.0
# Beds                                                             2.0
# Bed Type                                                    Real Bed
# Amenities          TV,Internet,Wireless Internet,Air conditioning...
# Square Feet                                                    915.0
# Price                                                           70.0
# Security Deposit                                                 NaN
# Cleaning Fee                                                    30.0
# Guests Included                                                    2
# Extra People                                                       8
# Minimum Nights                                                     3
# Number of Reviews                                                  7
# Reviews per Month                                               0.12

# %%
# 2.2 - Descripción (describe) es un método de pandas que nos muestra diferentes métricas de cada característica, que servirán para ver la relación de algunas 
# características (variables independientes) con el precio (variable dependiente).
# Parece ser que hay unos Outliers: los valores máximos de Accomodates, Bathrooms, Bedrooms, Beds, Cleaning Fee, Extra People parecen Outliers

#airbnb_Madrid_train = pd.read_csv('./airbnb_Madrid_train.csv', sep=';', decimal='.')
airbnb_Madrid_Nsf_train.describe()
# Out:
#             Zipcode    Latitude   Longitude  Accommodates   Bathrooms  \
# count    277.000000  282.000000  282.000000    282.000000  279.000000
# mean   28014.620939   40.420059   -3.696739      3.943262    1.310036
# std       12.278354    0.018297    0.025164      2.437177    0.625972
# min    28001.000000   40.355601   -3.781251      1.000000    0.000000
# 25%    28005.000000   40.410864   -3.707389      2.000000    1.000000
# 50%    28012.000000   40.416979   -3.702815      4.000000    1.000000
# 75%    28015.000000   40.425375   -3.695332      5.000000    1.500000
# max    28053.000000   40.491287   -3.576178     16.000000    5.000000
#
#          Bedrooms        Beds  Square Feet       Price  Security Deposit  \
# count  280.000000  282.000000   282.000000  281.000000        173.000000
# mean     1.464286    2.492908   612.258865   75.825623        166.976879
# std      0.979435    2.152947   532.060308   65.209181         72.544369
# min      0.000000    1.000000     8.000000   13.000000         80.000000
# 25%      1.000000    1.000000   177.500000   40.000000        100.000000
# 50%      1.000000    2.000000   538.000000   65.000000        150.000000
# 75%      2.000000    3.000000   807.000000   85.000000        200.000000
# max      6.000000   16.000000  2691.000000  500.000000        500.000000
#
#        Cleaning Fee  Guests Included  Extra People  Minimum Nights  \
# count    179.000000       282.000000    282.000000      282.000000
# mean      34.418994         1.921986     10.780142        8.340426
# std       20.778875         1.716866     17.542056       70.338564
# min        5.000000         1.000000      0.000000        1.000000
# 25%       20.000000         1.000000      0.000000        2.000000
# 50%       30.000000         2.000000     10.000000        2.000000
# 75%       45.000000         2.000000     15.000000        4.000000
# max      180.000000        16.000000    250.000000     1125.000000
#
#        Number of Reviews  Reviews per Month
# count         282.000000         265.000000
# mean           50.783688           1.214038
# std            67.161403           1.405733
# min             0.000000           0.020000
# 25%             7.000000           0.240000
# 50%            21.000000           0.610000
# 75%            73.750000           1.850000
# max           356.000000           8.310000

# %%
# 2.3 - Tipos de datos (dtypes)

airbnb_Madrid_Nsf_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Street             314 non-null    object
#  1   Neighbourhood      303 non-null    object
#  2   City               314 non-null    object
#  3   Zipcode            309 non-null    float64
#  4   Country            314 non-null    object
#  5   Property Type      314 non-null    object
#  6   Room Type          314 non-null    object
#  7   Accommodates       314 non-null    int64
#  8   Bathrooms          310 non-null    float64
#  9   Bedrooms           312 non-null    float64
#  10  Beds               314 non-null    float64
#  11  Bed Type           314 non-null    object
#  12  Amenities          314 non-null    object
#  13  Square Feet        314 non-null    float64
#  14  Price              313 non-null    float64
#  15  Security Deposit   197 non-null    float64
#  16  Cleaning Fee       199 non-null    float64
#  17  Guests Included    314 non-null    int64
#  18  Extra People       314 non-null    int64
#  19  Minimum Nights     314 non-null    int64
#  20  Number of Reviews  314 non-null    int64
#  21  Reviews per Month  295 non-null    float64
# dtypes: float64(9), int64(5), object(8)
# memory usage: 54.1+ KB

# %%
# Conversión de square feet en square meters

def sqft_to_m2(superficie):
    return superficie * 0.3048 * 0.3048

airbnb_Madrid_Nsf_train['Square Meters'] = sqft_to_m2(airbnb_Madrid_Nsf_train['Square Feet'])

# %%
# 2.4 - Is null.any devuelve si para cada característica hay algún null

airbnb_Madrid_Nsf_train.isnull().any()
# Out:
# Street               False
# Neighbourhood         True
# City                 False
# Zipcode               True
# Country              False
# Property Type        False
# Room Type            False
# Accommodates         False
# Bathrooms             True
# Bedrooms              True
# Beds                 False
# Bed Type             False
# Amenities            False
# Square Feet          False
# Price                 True
# Security Deposit      True
# Cleaning Fee          True
# Guests Included      False
# Extra People         False
# Minimum Nights       False
# Number of Reviews    False
# Reviews per Month     True
# Square Meters        False
# dtype: bool

# %%
# 2.5 - Solucionar los True de isnull sustituyendo por '0', o la media o la moda, según el caso

airbnb_Madrid_Nsf_train['Neighbourhood'].fillna('0', inplace=True)
airbnb_Madrid_Nsf_train['Zipcode'].fillna('0', inplace=True)
airbnb_Madrid_Nsf_train['Bathrooms'].fillna(airbnb_Madrid_Nsf_train['Bathrooms'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_train['Bedrooms'].fillna(airbnb_Madrid_Nsf_train['Bedrooms'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_train['Beds'].fillna(airbnb_Madrid_Nsf_train['Beds'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_train['Amenities'].fillna('0', inplace=True)
#airbnb_Madrid_train['Square Feet'].fillna(airbnb_Madrid_train['Square Feet'].mean(), inplace=True)
airbnb_Madrid_Nsf_train['Price'].fillna(airbnb_Madrid_Nsf_train['Price'].mean(), inplace=True)
airbnb_Madrid_Nsf_train['Security Deposit'].fillna(airbnb_Madrid_Nsf_train['Security Deposit'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_train['Cleaning Fee'].fillna(airbnb_Madrid_Nsf_train['Cleaning Fee'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_train['Reviews per Month'].fillna(airbnb_Madrid_Nsf_train['Reviews per Month'].mode()[0], inplace=True)
#airbnb_Madrid_train['Square Meters'].fillna(airbnb_Madrid_train['Square Meters'].mean(), inplace=True)

airbnb_Madrid_Nsf_train.isnull().any()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Bathrooms'].fillna(airbnb_Madrid_Nsf_train['Bathrooms'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Bedrooms'].fillna(airbnb_Madrid_Nsf_train['Bedrooms'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Beds'].fillna(airbnb_Madrid_Nsf_train['Beds'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Amenities'].fillna('0', inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Price'].fillna(airbnb_Madrid_Nsf_train['Price'].mean(), inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Security Deposit'].fillna(airbnb_Madrid_Nsf_train['Security Deposit'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Cleaning Fee'].fillna(airbnb_Madrid_Nsf_train['Cleaning Fee'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3835639871.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_train['Reviews per Month'].fillna(airbnb_Madrid_Nsf_train['Reviews per Month'].mode()[0], inplace=True)
# Street               False
# Neighbourhood        False
# City                 False
# Zipcode              False
# Country              False
# Property Type        False
# Room Type            False
# Accommodates         False
# Bathrooms            False
# Bedrooms             False
# Beds                 False
# Bed Type             False
# Amenities            False
# Square Feet          False
# Price                False
# Security Deposit     False
# Cleaning Fee         False
# Guests Included      False
# Extra People         False
# Minimum Nights       False
# Number of Reviews    False
# Reviews per Month    False
# Square Meters        False
# dtype: bool

# %%
# 2.6 - Correlación entre los datos. Primero creo otro dataframe con los datos correlacionables

airbnb_Madrid_Nsf_train_corr = airbnb_Madrid_Nsf_train.drop (['Street', 'Neighbourhood', 'City', 'Zipcode', 'Country', 'Property Type', 'Room Type', 'Bed Type', 'Amenities'], axis=1)  
airbnb_Madrid_Nsf_train_corr.corr()
# Out:
#                    Accommodates  Bathrooms  Bedrooms      Beds  Square Feet  \
# Accommodates           1.000000   0.609973  0.711304  0.856258     0.491195
# Bathrooms              0.609973   1.000000  0.561844  0.610134     0.569620
# Bedrooms               0.711304   0.561844  1.000000  0.646330     0.499400
# Beds                   0.856258   0.610134  0.646330  1.000000     0.497469
# Square Feet            0.491195   0.569620  0.499400  0.497469     1.000000
# Price                  0.451523   0.326418  0.484757  0.355947     0.348909
# Security Deposit       0.272102   0.285204  0.274245  0.198251     0.293586
# Cleaning Fee           0.366956   0.276950  0.418566  0.262023     0.252855
# Guests Included        0.314223   0.272070  0.339178  0.271179     0.205420
# Extra People           0.212348   0.205515  0.184391  0.177394     0.208276
# Minimum Nights         0.016064  -0.002852  0.009066 -0.022790     0.007057
# Number of Reviews     -0.033877  -0.101020 -0.038132 -0.040148    -0.040135
# Reviews per Month     -0.045229  -0.097414 -0.020337 -0.048772    -0.052691
# Square Meters          0.491195   0.569620  0.499400  0.497469     1.000000
#
#                       Price  Security Deposit  Cleaning Fee  Guests Included  \
# Accommodates       0.451523          0.272102      0.366956         0.314223
# Bathrooms          0.326418          0.285204      0.276950         0.272070
# Bedrooms           0.484757          0.274245      0.418566         0.339178
# Beds               0.355947          0.198251      0.262023         0.271179
# Square Feet        0.348909          0.293586      0.252855         0.205420
# Price              1.000000          0.332188      0.505464         0.307892
# Security Deposit   0.332188          1.000000      0.402189         0.074065
# Cleaning Fee       0.505464          0.402189      1.000000         0.080550
# Guests Included    0.307892          0.074065      0.080550         1.000000
# Extra People       0.067883          0.057558      0.213335         0.054448
# Minimum Nights     0.043224         -0.009741     -0.010283         0.023483
# Number of Reviews -0.054244         -0.155319     -0.089492        -0.045762
# Reviews per Month -0.047266         -0.123308     -0.088597        -0.017221
# Square Meters      0.348909          0.293586      0.252855         0.205420
#
#                    Extra People  Minimum Nights  Number of Reviews  \
# Accommodates           0.212348        0.016064          -0.033877
# Bathrooms              0.205515       -0.002852          -0.101020
# Bedrooms               0.184391        0.009066          -0.038132
# Beds                   0.177394       -0.022790          -0.040148
# Square Feet            0.208276        0.007057          -0.040135
# Price                  0.067883        0.043224          -0.054244
# Security Deposit       0.057558       -0.009741          -0.155319
# Cleaning Fee           0.213335       -0.010283          -0.089492
# Guests Included        0.054448        0.023483          -0.045762
# Extra People           1.000000       -0.016242          -0.057176
# Minimum Nights        -0.016242        1.000000          -0.061675
# Number of Reviews     -0.057176       -0.061675           1.000000
# Reviews per Month     -0.080527       -0.056889           0.937170
# Square Meters          0.208276        0.007057          -0.040135
#
#                    Reviews per Month  Square Meters
# Accommodates               -0.045229       0.491195
# Bathrooms                  -0.097414       0.569620
# Bedrooms                   -0.020337       0.499400
# Beds                       -0.048772       0.497469
# Square Feet                -0.052691       1.000000
# Price                      -0.047266       0.348909
# Security Deposit           -0.123308       0.293586
# Cleaning Fee               -0.088597       0.252855
# Guests Included            -0.017221       0.205420
# Extra People               -0.080527       0.208276
# Minimum Nights             -0.056889       0.007057
# Number of Reviews           0.937170      -0.040135
# Reviews per Month           1.000000      -0.052691
# Square Meters              -0.052691       1.000000

# %%
# 2.6.1 Representación gráfica de la correlación

import seaborn as sns

# Compute the correlation matrix
corr = np.abs(airbnb_Madrid_Nsf_train_corr.drop(['Price'], axis=1).corr())

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,vmin = 0.0, vmax=1.0, center=0.5,
            linewidths=.1, cmap="YlGnBu", cbar_kws={"shrink": .8})

plt.show()

# %%
# 2.7 - Conversión de los Square Feet en m2

#def sqft_to_m2(superficie):
#    return superficie * 0.092903

#airbnb_Madrid_train['Square Meters'] = sqft_to_m2(airbnb_Madrid_train['Square Feet'])

#airbnb_Madrid_train['Square Meters'].fillna(airbnb_Madrid_train['Square Meters'].mean(), inplace=True)

#airbnb_Madrid_train.head(4)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_26736\4243787473.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_train['Square Meters'].fillna(airbnb_Madrid_train['Square Meters'].mean(), inplace=True)
#                                              Street Neighbourhood    City  \
# 0                Madrid, Community of Madrid, Spain             0  Madrid
# 1          Madrid, Comunidad de Madrid 28017, Spain             0  Madrid
# 2  Cortes, Madrid, Comunidad de Madrid 28014, Spain        Cortes  Madrid
# 3     Sol, Madrid, Comunidad de Madrid 28013, Spain           Sol  Madrid
#
#   Zipcode Country Property Type        Room Type  Accommodates  Bathrooms  \
# 0       0   Spain     Apartment  Entire home/apt             4        1.0
# 1   28017   Spain         House     Private room             1        1.0
# 2   28014   Spain     Apartment  Entire home/apt             4        1.0
# 3   28013   Spain     Apartment  Entire home/apt             2        1.0
#
#    Bedrooms  ...  Square Feet  Price Security Deposit  Cleaning Fee  \
# 0       1.0  ...   374.084309   55.0            100.0          30.0
# 1       1.0  ...   374.084309   21.0            100.0          30.0
# 2       2.0  ...   374.084309  110.0            175.0          50.0
# 3       0.0  ...   374.084309   39.0            100.0          30.0
#
#    Guests Included  Extra People  Minimum Nights  Number of Reviews  \
# 0                1             0               1                 72
# 1                1             0               1                  0
# 2                4            15               2                 58
# 3                1             0               2                 11
#
#    Reviews per Month  Square Meters
# 0               7.63      34.753555
# 1               1.00      34.753555
# 2               2.28      34.753555
# 3               2.97      34.753555
#
# [4 rows x 23 columns]

# %%
# 2.8 - Visualizaciones de los principales datos
# 2.8.1 - Histogramas de variables por separado

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
airbnb_Madrid_Nsf_train['Bedrooms'].plot.hist(alpha=0.5, bins=25, grid = True)
plt.ylim(0, 1000)
plt.xlabel('Bedrooms')

plt.subplot(1,3,2)
airbnb_Madrid_Nsf_train['Square Meters'].plot.hist(alpha=0.5, bins=25, grid = True)
plt.yscale("log")
plt.xlabel('Square Meters')

plt.subplot(1,3,3)
airbnb_Madrid_Nsf_train['Bathrooms'].plot.hist(alpha=0.5, bins=25, grid = True)
plt.ylim(0, 1000)
plt.xlabel('Bathrooms')

plt.show()

# %%
# 2.8.2 - Gráficas del precio en función de las principales características

# Sólo representamos 3: bedrooms, sqm meters y bathrooms
# el resto se puede repetir una a una

airbnb_Madrid_Nsf_train.plot(kind = 'scatter',x='Bedrooms',y = 'Price')
plt.xlabel('# bedrooms')
plt.ylabel('price ($)')
plt.show()

airbnb_Madrid_Nsf_train.plot(kind = 'scatter',x='Square Meters',y = 'Price')
plt.xlabel('Square Meters ($m^2$)')
plt.ylabel('price ($)')
plt.show()

airbnb_Madrid_Nsf_train.plot(kind = 'scatter',x='Bathrooms',y = 'Price')
plt.xlabel('# Bathrooms')
plt.ylabel('price ($)')
plt.show()

# %%
# 2.8.3 - Eliminación de Outliers

# Según estas gráficas no hay Outliers, y revisando los máximos de .describe() tampoco parece que lo sean.

# %%
# 2.9 - Representación de todas las variables

pd.plotting.scatter_matrix(airbnb_Madrid_Nsf_train_corr, alpha=0.2, figsize=(20, 20), diagonal = 'kde')
plt.show()

# %%
# 3 - Preprocesado
# Hemos eliminado las variables que no son necesarias
# Ahora vamos a estudiar la selección Random Forest / Lasso

# %%
# 3.1 - Se cogen los datos de test y se aplican los resultados del análisis hecho en train

airbnb_Madrid_Nsf_test = pd.read_csv('./airbnb_Madrid_Nsf_test.csv', sep=';', decimal='.')

# Conversión de square feet en square meters

def sqft_to_m2(superficie):
    return superficie * 0.3048 * 0.3048

airbnb_Madrid_Nsf_test['Square Meters'] = sqft_to_m2(airbnb_Madrid_Nsf_test['Square Feet'])

# Solucionar isnull
airbnb_Madrid_Nsf_test['Neighbourhood'].fillna('0', inplace=True)
airbnb_Madrid_Nsf_test['Zipcode'].fillna('0', inplace=True)
airbnb_Madrid_Nsf_test['Bathrooms'].fillna(airbnb_Madrid_Nsf_test['Bathrooms'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_test['Bedrooms'].fillna(airbnb_Madrid_Nsf_test['Bedrooms'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_test['Beds'].fillna(airbnb_Madrid_Nsf_test['Beds'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_test['Amenities'].fillna('0', inplace=True)
airbnb_Madrid_Nsf_test['Square Feet'].fillna(airbnb_Madrid_Nsf_test['Square Feet'].mean(), inplace=True)
airbnb_Madrid_Nsf_test['Price'].fillna(airbnb_Madrid_Nsf_test['Price'].mean(), inplace=True)
airbnb_Madrid_Nsf_test['Security Deposit'].fillna(airbnb_Madrid_Nsf_test['Security Deposit'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_test['Cleaning Fee'].fillna(airbnb_Madrid_Nsf_test['Cleaning Fee'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_test['Reviews per Month'].fillna(airbnb_Madrid_Nsf_test['Reviews per Month'].mode()[0], inplace=True)
airbnb_Madrid_Nsf_test['Square Meters'].fillna(airbnb_Madrid_Nsf_test['Square Meters'].mean(), inplace=True)
airbnb_Madrid_Nsf_test.isnull().any()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Neighbourhood'].fillna('0', inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Zipcode'].fillna('0', inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Bathrooms'].fillna(airbnb_Madrid_Nsf_test['Bathrooms'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Bedrooms'].fillna(airbnb_Madrid_Nsf_test['Bedrooms'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Beds'].fillna(airbnb_Madrid_Nsf_test['Beds'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Amenities'].fillna('0', inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Square Feet'].fillna(airbnb_Madrid_Nsf_test['Square Feet'].mean(), inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Price'].fillna(airbnb_Madrid_Nsf_test['Price'].mean(), inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Security Deposit'].fillna(airbnb_Madrid_Nsf_test['Security Deposit'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Cleaning Fee'].fillna(airbnb_Madrid_Nsf_test['Cleaning Fee'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Reviews per Month'].fillna(airbnb_Madrid_Nsf_test['Reviews per Month'].mode()[0], inplace=True)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\3523138663.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_Madrid_Nsf_test['Square Meters'].fillna(airbnb_Madrid_Nsf_test['Square Meters'].mean(), inplace=True)
# Street               False
# Neighbourhood        False
# City                 False
# Zipcode              False
# Country              False
# Property Type        False
# Room Type            False
# Accommodates         False
# Bathrooms            False
# Bedrooms             False
# Beds                 False
# Bed Type             False
# Amenities            False
# Square Feet          False
# Price                False
# Security Deposit     False
# Cleaning Fee         False
# Guests Included      False
# Extra People         False
# Minimum Nights       False
# Number of Reviews    False
# Reviews per Month    False
# Square Meters        False
# dtype: bool

# %%
# Drop de los datos no correlacionables

airbnb_Madrid_Nsf_test_corr = airbnb_Madrid_Nsf_test.drop (['Street', 'Neighbourhood', 'City', 'Zipcode', 'Country', 'Property Type', 'Room Type', 'Bed Type', 'Amenities'], axis=1)  
#airbnb_Madrid_train_corr.corr()



# Segmentación de los datos separando variable dependiente de las independientes

X_train = airbnb_Madrid_Nsf_train_corr.drop(columns=['Price']) 
y_train = airbnb_Madrid_Nsf_train_corr.Price
X_test = airbnb_Madrid_Nsf_test_corr.drop(columns=['Price']) 
y_test = airbnb_Madrid_Nsf_test_corr.Price

print(X_train.isna().sum())
# Out:
# Accommodates         0
# Bathrooms            0
# Bedrooms             0
# Beds                 0
# Square Feet          0
# Security Deposit     0
# Cleaning Fee         0
# Guests Included      0
# Extra People         0
# Minimum Nights       0
# Number of Reviews    0
# Reviews per Month    0
# Square Meters        0
# dtype: int64

# %%
# 3.2 - Aplicación de Random Forest

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

maxDepth = range(1,15)
tuned_parameters = {'max_depth': maxDepth}

grid = GridSearchCV(RandomForestRegressor(random_state=0, n_estimators=200, max_features='sqrt'), param_grid=tuned_parameters,cv=3, verbose=2) 
grid.fit(X_train, y_train)

print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))
#print(y_train.isna().sum()) 

scores = np.array(grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth')
plt.ylabel('10-fold ACC')

plt.show()
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# [CV] END ........................................max_depth=1; total time=   0.1s
# [CV] END ........................................max_depth=1; total time=   0.1s
# [CV] END ........................................max_depth=1; total time=   0.1s
# [CV] END ........................................max_depth=2; total time=   0.1s
# [CV] END ........................................max_depth=2; total time=   0.1s
# [CV] END ........................................max_depth=2; total time=   0.2s
# [CV] END ........................................max_depth=3; total time=   0.3s
# [CV] END ........................................max_depth=3; total time=   0.5s
# [CV] END ........................................max_depth=3; total time=   0.3s
# [CV] END ........................................max_depth=4; total time=   0.2s
# [CV] END ........................................max_depth=4; total time=   0.1s
# [CV] END ........................................max_depth=4; total time=   0.2s
# [CV] END ........................................max_depth=5; total time=   0.2s
# [CV] END ........................................max_depth=5; total time=   0.2s
# [CV] END ........................................max_depth=5; total time=   0.3s
# [CV] END ........................................max_depth=6; total time=   0.2s
# [CV] END ........................................max_depth=6; total time=   0.2s
# [CV] END ........................................max_depth=6; total time=   0.2s
# [CV] END ........................................max_depth=7; total time=   0.3s
# [CV] END ........................................max_depth=7; total time=   0.6s
# [CV] END ........................................max_depth=7; total time=   0.5s
# [CV] END ........................................max_depth=8; total time=   0.2s
# [CV] END ........................................max_depth=8; total time=   0.2s
# [CV] END ........................................max_depth=8; total time=   0.1s
# [CV] END ........................................max_depth=9; total time=   0.2s
# [CV] END ........................................max_depth=9; total time=   0.3s
# [CV] END ........................................max_depth=9; total time=   0.4s
# [CV] END .......................................max_depth=10; total time=   0.5s
# [CV] END .......................................max_depth=10; total time=   0.3s
# [CV] END .......................................max_depth=10; total time=   0.2s
# [CV] END .......................................max_depth=11; total time=   0.2s
# [CV] END .......................................max_depth=11; total time=   0.1s
# [CV] END .......................................max_depth=11; total time=   0.2s
# [CV] END .......................................max_depth=12; total time=   0.2s
# [CV] END .......................................max_depth=12; total time=   0.4s
# [CV] END .......................................max_depth=12; total time=   0.4s
# [CV] END .......................................max_depth=13; total time=   0.4s
# [CV] END .......................................max_depth=13; total time=   0.1s
# [CV] END .......................................max_depth=13; total time=   0.1s
# [CV] END .......................................max_depth=14; total time=   0.1s
# [CV] END .......................................max_depth=14; total time=   0.1s
# [CV] END .......................................max_depth=14; total time=   0.1s
# best mean cross-validation score: 0.408
# best parameters: {'max_depth': 7}

# %%
# Vemos que el modelo no es bueno, porque sale un valor de Accuracy de 0,408. Sería bueno si se acercara más a 1. Hay que ajustar

# %%
# 3.2 - Aplicación de Lasso

from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

degree = 5

#model
alpha = 0.1
lasso = Lasso(alpha = alpha).fit(X_train,y_train)
w = lasso.coef_
norm_w2 = np.dot(w,w.T)
    
# predicción
y_hat = lasso.predict(X_test)

# error
error_test = np.mean(np.power(y_test - y_hat,2)) 


# Definición de variables
x = X_test  # First feature in the test set (if it's univariate)
y_i = y_test  # Actual target values for the test set
#y_hat = model.predict(X_test)  # Predictions from the model for the test set

# g_x can be defined similarly if you are plotting model predictions
#g_x = lasso.predict(x.reshape(-1, 1))  # Model prediction on the test data
g_x = lasso.predict(x)  # Model prediction on the test data

plt.plot(x, g_x, 'r', label='$y$')  # Model's predicted values
plt.plot(x, y_i, 'b.', label='$y_i$')  # Actual test values
#plt.plot(x, y_hat, 'g', label='$\hat{y}$')  # Predicted y-values
#plt.title(f'Grado: {degree}, MSE:{error_test:.2f}\nalpha: {alpha:g}, $||w||_2^2$ = {norm_w2:.2g}')
plt.title(f'MSE:{error_test:.2f}\nalpha: {alpha:g}, $||w||_2^2$ = {norm_w2:.2g}')
plt.legend()
plt.xlim((0, 100))
plt.ylim((-10, 125))
plt.show()

coef_names = ['w' + str(i) + ': ' for i in range(1,degree+1)]

for f,wi in zip(coef_names,w):
    print(f,wi)
# Out:
# C:\Users\usuario\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.226e+05, tolerance: 1.329e+02
#   model = cd_fast.enet_coordinate_descent(
# w1:  4.847351452682565
# w2:  -3.85734133394441
# w3:  10.242335438442105
# w4:  -2.045121504310757
# w5:  0.023094050658107247

# %%
# 3.2 - Aplicación de Lasso (de Chat GPT)

# Importar las bibliotecas necesarias
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error


# Crear un modelo Lasso
lasso_model = Lasso(alpha=0.1)  # 'alpha' es el parámetro de regularización (hiperparámetro)

# Entrenar el modelo
lasso_model.fit(X_train, y_train)

# Hacer predicciones en el conjunto de prueba
y_pred = lasso_model.predict(X_test)

# Evaluar el modelo utilizando el error cuadrático medio (MSE)
mse = mean_squared_error(y_test, y_pred)
print(f"Error cuadrático medio (MSE) en el conjunto de prueba: {mse:.4f}")

# Ver los coeficientes de las características
print("Coeficientes del modelo Lasso:", lasso_model.coef_)

# Ver las características seleccionadas (coeficientes diferentes de cero)
selected_features = X_test.columns[lasso_model.coef_ != 0]
print("Características seleccionadas por el modelo Lasso:", selected_features)
# Out:
# Error cuadrático medio (MSE) en el conjunto de prueba: 1888.6644
# Coeficientes del modelo Lasso: [ 4.84735145 -3.85734133 10.24233544 -2.0451215   0.02309405  0.09519439
#   1.31287255  6.88896464 -0.34543095  0.0347937   0.01756519 -0.64463122
#  -0.11965068]
# Características seleccionadas por el modelo Lasso: Index(['Accommodates', 'Bathrooms', 'Bedrooms', 'Beds', 'Square Feet',
#        'Security Deposit', 'Cleaning Fee', 'Guests Included', 'Extra People',
#        'Minimum Nights', 'Number of Reviews', 'Reviews per Month',
#        'Square Meters'],
#       dtype='object')
# C:\Users\usuario\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.226e+05, tolerance: 1.329e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
# 3.3 - Aplicación de un modelo base (simple) de regresión lineal con las variables, escojo m2, bedrooms, Accomodates, Bathrooms, Cleaning Fee, minimum nights
# para comparar el error MSE

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression 

degree = 5

# features
poly = PolynomialFeatures(degree) # generamos x^j
X_train_RL = X_train.drop(columns=['Security Deposit', 'Guests Included', 'Extra People', 'Number of Reviews', 'Reviews per Month'])

y_train_RL = y_train

X_test_RL = X_test.drop(columns=['Security Deposit', 'Guests Included', 'Extra People', 'Number of Reviews', 'Reviews per Month'])

y_test_RL = y_test

# Pintar dimensiones de los 4
print(X_train_RL.shape)
print(y_train_RL.shape)
print(X_test_RL.shape)
print(y_test_RL.shape)


# pista: como siempre, instanciar el modelo y .fit()
lr = LinearRegression().fit(X_train_RL, y_train_RL)

# predicción
y_hat = lr.predict(X_test_RL)

# Cálculo del error
mse = np.mean((y_test_RL-y_hat)**2)

# Identificación de variables
x = X_train_RL
g_x = y_train_RL
x_i = X_test_RL
y_i = y_test_RL

# Representación gráfica

#plt.plot(x,g_x,'r',label='$y$')
plt.plot(x_i,y_i,'b.',label='$y_i$')
plt.plot(x_i,y_hat,'g',label='$\hat{y}$')
plt.title(f'Grado: {degree}\nMSE: {mse:.2f}')
plt.legend()
#plt.xlim((0, 1))
#plt.ylim((-2, 2))
plt.show()

# Mostramos los coeficientes del modelo
print('w0: ', lr.intercept_)

w = lr.coef_
norm_w2 = np.dot(w,w.T) # no se tiene en cuenta el intercepto

coef_names = ['w' + str(i) + ': ' for i in range(1,degree+1)]
for f,wi in zip(coef_names,w):
    print(f,wi)

print(f'\n||w||_2^2 = {norm_w2:.2g}')
# Out:
# <>:45: SyntaxWarning: invalid escape sequence '\h'
# <>:45: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7400\775021014.py:45: SyntaxWarning: invalid escape sequence '\h'
#   plt.plot(x_i,y_hat,'g',label='$\hat{y}$')
# (314, 8)
# (314,)
# (12893, 8)
# (12893,)
# w0:  -7.5167789532880676
# w1:  5.851767933285915
# w2:  -2.3587440166964213
# w3:  13.451861189117304
# w4:  -2.83949978001398
# w5:  0.012514281870268238
#
# ||w||_2^2 = 2.3e+02

# %%
# 4 - Aplicación de cross-validation manualmente

from sklearn.model_selection import KFold

# Crear el objeto KFold
kf = KFold(n_splits=5)

# Iterar sobre los splits y entrenar/validar el modelo
scores = []
for train_index, test_index in kf.split(X_train):
    X_train_CV, X_test_CV = X_train[train_index], X_test[test_index]
    y_train_CV, y_test_CV = y_train[train_index], y_test[test_index]
    
    # Entrenar el modelo
    model.fit(X_train_CV, y_train_CV)
    
    # Evaluar el modelo
    score = model.score(X_test_CV, y_test_CV)
    scores.append(score)

print("Scores de cada fold: ", scores)
print("Promedio de la validación cruzada: ", sum(scores)/len(scores))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 11
#       9 scores = []
#      10 for train_index, test_index in kf.split(X_train):
# ---> 11     X_train_CV, X_test_CV = X_train[train_index], X_test[test_index]
#      12     y_train_CV, y_test_CV = y_train[train_index], y_test[test_index]
#      14     # Entrenar el modelo
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([ 63,  64,  65,  66,  67,  68,  69,  70,  71,  72,\n       ...\n       304, 305, 306, 307, 308, 309, 310, 311, 312, 313],\n      dtype='int32', length=251)] are in the [columns]"
